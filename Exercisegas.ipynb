# %% [markdown]
# ## US Oil and Gas Production
#
# Analysing the [Kaggle Dataset](https://www.kaggle.com/djzurawski/us-oil-and-gas-production-june-2008-to-june-2018) with information about Oil and Gas production in the US from June 2008 to June 2018.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %% [markdown]
# ---
#
# Let's load the Gas production:

# %%
file = "US_natural_gas_production.csv"
gas_df = pd.read_csv("US_natural_gas_production.csv")
gas_df.head(3)
# Out:
#         Month   U.S.  Alaska  Arkansas  Kansas  Other States  \
# 0  2008-06-01  70626    8875      1196    1024          2995
# 1  2008-07-01  71137    8375      1256    1034          3150
# 2  2008-08-01  70760    8739      1313    1033          3092
#
#    Federal Offshore--Gulf of Mexico  Wyoming  West Virginia  Utah  \
# 0                              7339     6839            670  1198
# 1                              7468     6940            674  1200
# 2                              6868     6835            678  1277
#
#    Pennsylvania  Texas  Oklahoma  Ohio  North Dakota  New Mexico  Montana  \
# 0           540  21446      5241   224           243        3975      323
# 1           512  21547      5256   220           243        4179      324
# 2           529  21777      4896   220           249        4092      327
#
#    Louisiana  Colorado  California
# 0       3989      3576         932
# 1       4008      3834         919
# 2       3896      4056         881

# %% [markdown]
# # Estructura del data frame

# %%
gas_df.shape
# Out:
# (121, 20)

# %% [markdown]
# # Size del data frame

# %%
gas_df.columns
# Out:
# Index(['Month', 'U.S.', 'Alaska', 'Arkansas', 'Kansas', 'Other States',
#        'Federal Offshore--Gulf of Mexico', 'Wyoming', 'West Virginia', 'Utah',
#        'Pennsylvania', 'Texas', 'Oklahoma', 'Ohio', 'North Dakota',
#        'New Mexico', 'Montana', 'Louisiana', 'Colorado', 'California'],
#       dtype='object')

# %% [markdown]
# # Verificando los tipos de las primeras dos columnas.

# %%
gas_df.dtypes[0:2]
# Out:
# Month    object
# U.S.      int64
# dtype: object

# %% [markdown]
# # Conversión de la columna Month a datetime

# %%
gas_df['Month'] = pd.to_datetime(gas_df['Month'], format='%Y-%m-%d')

# %%
gas_df.head(3)
# Out:
#        Month   U.S.  Alaska  Arkansas  Kansas  Other States  \
# 0 2008-06-01  70626    8875      1196    1024          2995
# 1 2008-07-01  71137    8375      1256    1034          3150
# 2 2008-08-01  70760    8739      1313    1033          3092
#
#    Federal Offshore--Gulf of Mexico  Wyoming  West Virginia  Utah  \
# 0                              7339     6839            670  1198
# 1                              7468     6940            674  1200
# 2                              6868     6835            678  1277
#
#    Pennsylvania  Texas  Oklahoma  Ohio  North Dakota  New Mexico  Montana  \
# 0           540  21446      5241   224           243        3975      323
# 1           512  21547      5256   220           243        4179      324
# 2           529  21777      4896   220           249        4092      327
#
#    Louisiana  Colorado  California
# 0       3989      3576         932
# 1       4008      3834         919
# 2       3896      4056         881

# %%
gas_df.dtypes[0:2]
# Out:
# Month    datetime64[ns]
# U.S.              int64
# dtype: object

# %%
gas_df['Month'].dt.year.head()
# Out:
# 0    2008
# 1    2008
# 2    2008
# 3    2008
# 4    2008
# Name: Month, dtype: int32

# %%
gas_df['Month'].dt.month.tail()
# Out:
# 116    2
# 117    3
# 118    4
# 119    5
# 120    6
# Name: Month, dtype: int32

# %%
gas_df['Month'] = pd.to_datetime(gas_df['Month'], format='%Y-%m-%d')

# %%
gas_df.dtypes
# Out:
# Month                               datetime64[ns]
# U.S.                                         int64
# Alaska                                       int64
# Arkansas                                     int64
# Kansas                                       int64
# Other States                                 int64
# Federal Offshore--Gulf of Mexico             int64
# Wyoming                                      int64
# West Virginia                                int64
# Utah                                         int64
# Pennsylvania                                 int64
# Texas                                        int64
# Oklahoma                                     int64
# Ohio                                         int64
# North Dakota                                 int64
# New Mexico                                   int64
# Montana                                      int64
# Louisiana                                    int64
# Colorado                                     int64
# California                                   int64
# dtype: object

# %% [markdown]
# ## Yearly Gas production

# %%
yearly_gas_df = gas_df.groupby(gas_df['Month'].dt.year).median()
yearly_gas_df
# Out:
#                     Month     U.S.  Alaska  Arkansas  Kansas  Other States  \
# Month
# 2008  2008-09-01 00:00:00  70760.0  9221.0    1316.0  1032.0        3092.0
# 2009  2009-06-16 00:00:00  71113.5  9211.0    1827.5   980.0        2962.5
# 2010  2010-06-16 00:00:00  73072.5  9248.0    2549.5   900.5        3091.0
# 2011  2011-06-16 00:00:00  77770.0  8775.0    2978.0   850.0        3183.0
# 2012  2012-06-16 00:00:00  80982.0  9234.0    3111.0   810.0        3080.5
# 2013  2013-06-16 00:00:00  81039.5  8883.0    3122.0   795.0        1877.5
# 2014  2014-06-16 00:00:00  85327.5  8998.5    3075.0   785.0        1734.5
# 2015  2015-06-16 00:00:00  90273.0  9051.5    2772.5   761.5        1672.0
# 2016  2016-06-16 00:00:00  88773.0  8728.0    2215.0   668.0        1542.0
# 2017  2017-06-16 00:00:00  89404.0  9334.0    1925.0   605.0        1426.0
# 2018  2018-03-16 12:00:00  98353.0  9483.0    1663.0   566.5        1350.0
#
#        Federal Offshore--Gulf of Mexico  Wyoming  West Virginia    Utah  \
# Month
# 2008                             5672.0   6909.0          674.0  1259.0
# 2009                             6680.5   7029.0          732.0  1223.0
# 2010                             6076.5   6865.0          728.0  1200.0
# 2011                             4959.5   6528.0         1098.0  1286.5
# 2012                             4162.5   6073.5         1430.5  1344.5
# 2013                             3613.5   5606.5         2138.0  1298.0
# 2014                             3546.0   5481.5         2887.0  1256.5
# 2015                             3585.5   5440.5         3636.5  1181.0
# 2016                             3321.0   5086.5         3769.0   983.5
# 2017                             3000.5   4698.0         4363.5   858.5
# 2018                             2567.5   4824.0         4688.5   825.5
#
#        Pennsylvania    Texas  Oklahoma    Ohio  North Dakota  New Mexico  \
# Month
# 2008          540.0  21777.0    5224.0   224.0         249.0      4078.0
# 2009          747.5  20915.0    5251.5   243.5         252.5      3920.5
# 2010         1531.5  20821.0    5004.5   214.0         314.5      3691.0
# 2011         3431.5  21767.5    5191.5   216.0         415.5      3568.5
# 2012         6162.5  22202.5    5534.5   231.0         710.0      3488.0
# 2013         8923.0  22819.0    5461.0   446.0         952.5      3452.0
# 2014        11661.0  23960.5    6505.5  1366.5        1274.0      3473.5
# 2015        13190.0  24235.0    6849.0  2706.0        1634.5      3593.0
# 2016        14568.0  22537.0    6789.0  3940.5        1655.5      3534.0
# 2017        14818.0  21605.5    6830.5  4841.0        1874.5      3624.0
# 2018        16324.0  22924.0    7799.5  6147.5        2179.5      3992.0
#
#        Montana  Louisiana  Colorado  California
# Month
# 2008     326.0     3896.0    3978.0       882.0
# 2009     289.0     4177.0    4148.5       847.5
# 2010     257.0     6174.0    4342.5       883.0
# 2011     218.5     8311.0    4506.5       766.5
# 2012     177.5     8088.5    4624.5       675.0
# 2013     173.0     6579.0    4449.5       694.5
# 2014     163.0     5425.5    4519.0       645.5
# 2015     161.5     4931.5    4622.0       640.0
# 2016     142.0     4764.5    4652.5       559.5
# 2017     131.5     5753.5    4618.5       553.5
# 2018     123.0     7459.5    4884.0       546.0

# %%
np.logical_and(yearly_gas_df.index >= 2009, yearly_gas_df.index <= 2017)
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False])

# %%
full_years = np.logical_and(yearly_gas_df.index >= 2009, yearly_gas_df.index <= 2017)
full_yearly_gas_df = yearly_gas_df[full_years]
plot = full_yearly_gas_df.filter(items=['U.S.']).plot(kind="bar")
plot.set_xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ### State production
#
# Let's have a look at the yearly production of some specific states

# %%
full_yearly_gas_df.columns[1:].sort_values()
# Out:
# Index(['Alaska', 'Arkansas', 'California', 'Colorado',
#        'Federal Offshore--Gulf of Mexico', 'Kansas', 'Louisiana', 'Montana',
#        'New Mexico', 'North Dakota', 'Ohio', 'Oklahoma', 'Other States',
#        'Pennsylvania', 'Texas', 'U.S.', 'Utah', 'West Virginia', 'Wyoming'],
#       dtype='object')

# %%
plot = full_yearly_gas_df.filter(items=['Colorado', 'Louisiana', 'Ohio', 'Utah']).plot()
plot.set_xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ---
#
# ## Comparing with Crude Oil Production

# %%
file = "US_crude_oil_production.csv"
oil_df = pd.read_csv(file)
oil_df.head()
# Out:
#         Month  U.S. Crude Oil   Alabama  Alaska  Arkansas  Arizona  \
# 0  2008-06-01             5138       21     655        17        0
# 1  2008-07-01             5177       21     640        17        0
# 2  2008-08-01             5003       21     544        17        0
# 3  2008-09-01             3974       21     681        16        0
# 4  2008-10-01             4738       21     716        17        0
#
#    California  Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# 0         583        82                                       1326
# 1         586        81                                       1372
# 2         588        82                                       1272
# 3         587        88                                        242
# 4         586        86                                        803
#
#    Federal Offshore Pacific Crude Oil  ...  Ohio  Oklahoma  Pennsylvania  \
# 0                                  67  ...    14       186             8
# 1                                  61  ...    14       184             8
# 2                                  70  ...    14       188             8
# 3                                  67  ...    14       186             8
# 4                                  66  ...    14       185             8
#
#    South Dakota  Wyoming  West Virginia  Virginia  Utah  Texas  Tennessee
# 0             5      144              6         0    60   1097          1
# 1             5      145              5         0    61   1111          1
# 2             5      145              6         0    62   1110          1
# 3             5      144              6         0    63   1055          1
# 4             5      145              6         0    64   1125          1
#
# [5 rows x 36 columns]

# %%
oil_df['Month'] = pd.to_datetime(oil_df['Month'], format='%Y-%m-%d')

# %%
yearly_gas = gas_df.groupby(gas_df['Month'].dt.year).median().filter(items=['U.S.'])
yearly_gas.columns = [ 'Gas' ]
yearly_gas.head(3)
# Out:
#            Gas
# Month
# 2008   70760.0
# 2009   71113.5
# 2010   73072.5
