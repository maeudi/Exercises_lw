# %% [markdown]
# <h1>Import Libraries</h1>

# %%
import numpy as np
import pandas as pd

# %%
countries_df= pd.read_csv('countries.csv',decimal=',')

# %%
type(countries_df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(countries_df)
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
countries_df.shape
# Out:
# (227, 20)

# %%
countries_df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
countries_df.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %%
countries_df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
countries_df.head(10)
# Out:
#               Country                               Region  Population  \
# 0        Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1            Albania   EASTERN EUROPE                          3581655
# 2            Algeria   NORTHERN AFRICA                        32930091
# 3     American Samoa   OCEANIA                                   57794
# 4            Andorra   WESTERN EUROPE                            71201
# 5             Angola   SUB-SAHARAN AFRICA                     12127071
# 6           Anguilla               LATIN AMER. & CARIB           13477
# 7  Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8          Argentina               LATIN AMER. & CARIB        39921833
# 9            Armenia                  C.W. OF IND. STATES      2976372
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# ...

# %%
countries_df.tail()
# Out:
#              Country                               Region  Population  \
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
# 224          527970                        40.6                          0.36
# 225          752614                        15.3                          0.00
# 226          390580                        31.3                          0.00
#
# ...

# %%
countries_df['Country']
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 222         West Bank
# 223    Western Sahara
# 224             Yemen
# 225            Zambia
# 226          Zimbabwe
# Name: Country, Length: 227, dtype: object

# %%
countries_df['Region'].unique()
# Out:
# array(['ASIA (EX. NEAR EAST)         ',
#        'EASTERN EUROPE                     ',
#        'NORTHERN AFRICA                    ',
#        'OCEANIA                            ',
#        'WESTERN EUROPE                     ',
#        'SUB-SAHARAN AFRICA                 ', 'LATIN AMER. & CARIB    ',
#        'C.W. OF IND. STATES ', 'NEAR EAST                          ',
#        'NORTHERN AMERICA                   ',
#        'BALTICS                            '], dtype=object)

# %%
american= countries_df['Region'].str.contains('AMER')
countries_df[american].head()
# Out:
#                Country                   Region  Population  Area (sq. mi.)  \
# 6            Anguilla   LATIN AMER. & CARIB           13477             102
# 7   Antigua & Barbuda   LATIN AMER. & CARIB           69108             443
# 8           Argentina   LATIN AMER. & CARIB        39921833         2766890
# 10              Aruba   LATIN AMER. & CARIB           71891             193
# 14       Bahamas, The   LATIN AMER. & CARIB          303770           13940
#
#     Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 6                        132.1                         59.80          10.76
# 7                        156.0                         34.54          -6.15
# 8                         14.4                          0.18           0.61
# 10                       372.5                         35.49           0.00
# 14                        21.8                         25.41          -2.20
#
# ...

# %%
american.unique()
# Out:
# array([False,  True])

# %%
countries_df[american].head(10)['Country']
# Out:
# 6              Anguilla
# 7     Antigua & Barbuda
# 8             Argentina
# 10                Aruba
# 14         Bahamas, The
# 17             Barbados
# 20               Belize
# 22              Bermuda
# 24              Bolivia
# 27               Brazil
# Name: Country, dtype: object

# %%
countries_df['Region']= countries_df['Region'].map(str.strip)

# %%
european= countries_df['Region'].isin(['WESTERN EUROPE','EASTERN EUROPE'])

# %%
countries_df[european].shape
# Out:
# (40, 20)

# %%
countries_df.set_index('Country',inplace=True)

# %%
countries_df.filter(regex='^D',axis='rows')
# Out:
#                                   Region  Population  Area (sq. mi.)  \
# Country
# Denmark                   WESTERN EUROPE     5450661           43094
# Djibouti              SUB-SAHARAN AFRICA      486530           23000
# Dominica             LATIN AMER. & CARIB       68910             754
# Dominican Republic   LATIN AMER. & CARIB     9183984           48730
#
#                      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# Country
# Denmark                                   126.5                         16.97
# Djibouti                                   21.2                          1.37
# Dominica                                   91.4                         19.63
# Dominican Republic                        188.5                          2.64
#
#                      Net migration  Infant mortality (per 1000 births)  \
# Country
# Denmark                       2.48                                4.56
# ...

# %% [markdown]
# # Sorting

# %%
countries_df.sort_index(ascending=True)
# Out:
#                                Region  Population  Area (sq. mi.)  \
# Country
# Afghanistan      ASIA (EX. NEAR EAST)    31056997          647500
# Albania                EASTERN EUROPE     3581655           28748
# Algeria               NORTHERN AFRICA    32930091         2381740
# American Samoa                OCEANIA       57794             199
# Andorra                WESTERN EUROPE       71201             468
# ...                               ...         ...             ...
# West Bank                   NEAR EAST     2460492            5860
# Western Sahara        NORTHERN AFRICA      273008          266000
# Yemen                       NEAR EAST    21456188          527970
# Zambia             SUB-SAHARAN AFRICA    11502010          752614
# Zimbabwe           SUB-SAHARAN AFRICA    12236805          390580
#
#                  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# Country
# Afghanistan                            48.0                          0.00
# ...

# %%
countries_df.sort_values('Population',ascending=False)
# Out:
#                                      Region  Population  Area (sq. mi.)  \
# Country
# China                  ASIA (EX. NEAR EAST)  1313973713         9596960
# India                  ASIA (EX. NEAR EAST)  1095351995         3287590
# United States              NORTHERN AMERICA   298444215         9631420
# Indonesia              ASIA (EX. NEAR EAST)   245452739         1919440
# Brazil                  LATIN AMER. & CARIB   188078227         8511965
# ...                                     ...         ...             ...
# Nauru                               OCEANIA       13287              21
# Tuvalu                              OCEANIA       11810              26
# Montserrat              LATIN AMER. & CARIB        9439             102
# Saint Helena             SUB-SAHARAN AFRICA        7502             413
# St Pierre & Miquelon       NORTHERN AMERICA        7026             242
#
#                        Pop. Density (per sq. mi.)  \
# Country
# ...

# %%
columns=['Country','Population','Area (sq. mi.)']
countries_df.sort_values('Population',ascending=False).filter(items=columns)
# Out:
#                        Population  Area (sq. mi.)
# Country
# China                  1313973713         9596960
# India                  1095351995         3287590
# United States           298444215         9631420
# Indonesia               245452739         1919440
# Brazil                  188078227         8511965
# ...                           ...             ...
# Nauru                       13287              21
# Tuvalu                      11810              26
# Montserrat                   9439             102
# Saint Helena                 7502             413
# St Pierre & Miquelon         7026             242
#
# [227 rows x 2 columns]

# %% [markdown]
# # Grouping

# %%
regions= countries_df.groupby('Region')

# %%
(regions[['Population','Area (sq. mi.)']].sum()/1_000_000).round(1)
# Out:
#                       Population  Area (sq. mi.)
# Region
# ASIA (EX. NEAR EAST)      3688.0            23.1
# BALTICS                      7.2             0.2
# C.W. OF IND. STATES        280.1            22.1
# EASTERN EUROPE             119.9             1.2
# LATIN AMER. & CARIB        561.8            20.5
# NEAR EAST                  195.1             4.4
# NORTHERN AFRICA            161.4             6.0
# NORTHERN AMERICA           331.7            21.8
# OCEANIA                     33.1             8.5
# SUB-SAHARAN AFRICA         749.4            24.3
# WESTERN EUROPE             396.3             3.7

# %%
regions['Pop. Density (per sq. mi.)'].mean().sort_values(ascending=False)
# Out:
# Region
# ASIA (EX. NEAR EAST)    1264.825000
# WESTERN EUROPE           952.042857
# NEAR EAST                427.081250
# NORTHERN AMERICA         260.860000
# LATIN AMER. & CARIB      136.202222
# OCEANIA                  131.180952
# EASTERN EUROPE           100.900000
# SUB-SAHARAN AFRICA        92.264706
# C.W. OF IND. STATES       56.708333
# BALTICS                   39.833333
# NORTHERN AFRICA           38.933333
# Name: Pop. Density (per sq. mi.), dtype: float64

# %%
regions.agg({'Population':np.sum,
             'GDP ($ per capita)':np.mean}).round(1).sort_values('GDP ($ per capita)',ascending=False)
# Out:
# /tmp/ipykernel_1120/923103137.py:1: FutureWarning: The provided callable <function sum at 0x7ff3ac0fb130> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   regions.agg({'Population':np.sum,
# /tmp/ipykernel_1120/923103137.py:1: FutureWarning: The provided callable <function mean at 0x7ff3ac1200d0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   regions.agg({'Population':np.sum,
#                       Population  GDP ($ per capita)
# Region
# WESTERN EUROPE         396339998             27046.4
# NORTHERN AMERICA       331672307             26100.0
# BALTICS                  7184974             11300.0
# NEAR EAST              195068377             10456.2
# EASTERN EUROPE         119914717              9808.3
# ...

# %% [markdown]
# # Boolean Indexing

# %%
big_countries=countries_df['Population']>200_000_000

# %%
countries_df[big_countries]
# Out:
#                               Region  Population  Area (sq. mi.)  \
# Country
# China           ASIA (EX. NEAR EAST)  1313973713         9596960
# India           ASIA (EX. NEAR EAST)  1095351995         3287590
# Indonesia       ASIA (EX. NEAR EAST)   245452739         1919440
# United States       NORTHERN AMERICA   298444215         9631420
#
#                 Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# Country
# China                                136.9                          0.15
# India                                333.2                          0.21
# Indonesia                            127.9                          2.85
# United States                         31.0                          0.21
#
#                 Net migration  Infant mortality (per 1000 births)  \
# Country
# China                   -0.40                               24.18
# India                   -0.07                               56.29
# ...

# %% [markdown]
# # Plotting

# %%
import matplotlib
# %matplotlib inline

# %%
column='GDP ($ per capita)'
top_ten_gpd = countries_df.sort_values(column,ascending=False).head(10)[column]
top_ten_gpd.plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>
